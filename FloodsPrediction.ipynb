# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('rainfall.csv')

# %%
df
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
df = df.drop(['Jan-Feb','Mar-May','Jun-Sep','Oct-Dec','ANNUAL'],axis = 1)

# %%
TG = df[df['SUBDIVISION']=='TELANGANA']

# %%
TG.reset_index(inplace = True)

# %%
TG
# Out:
#      index SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL  \
# 0     3197   TELANGANA  1901   6.9  41.8   7.8  45.2  22.0  123.6  237.8
# 1     3198   TELANGANA  1902   0.0   0.0   0.2  10.7   7.3   52.4  146.3
# 2     3199   TELANGANA  1903  12.9   4.6   0.0   9.9  40.7   99.2  505.2
# 3     3200   TELANGANA  1904   0.0   0.0  10.8   0.8  14.7  104.2  139.5
# 4     3201   TELANGANA  1905   0.0   4.3  12.8  27.6  32.2  129.5   82.4
# ..     ...         ...   ...   ...   ...   ...   ...   ...    ...    ...
# 110   3307   TELANGANA  2011   0.0  11.9   2.6  25.6   9.3   83.9  268.2
# 111   3308   TELANGANA  2012   6.7   0.0   0.2  14.0   8.4  124.4  300.3
# 112   3309   TELANGANA  2013   2.4  29.0   0.2  24.4   8.5  213.4  453.8
# 113   3310   TELANGANA  2014   0.2   2.9  58.3  10.3  73.3   62.3  146.0
# 114   3311   TELANGANA  2015  17.5   0.0  43.0  65.7  23.3  266.9  104.4
#
#        AUG    SEP    OCT   NOV  DEC
# 0    177.2   77.7   75.5  12.2  0.0
# ...

# %%
TG = TG.drop(['index'],axis = 1)

# %%
TG
# Out:
#     SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL    AUG  \
# 0     TELANGANA  1901   6.9  41.8   7.8  45.2  22.0  123.6  237.8  177.2
# 1     TELANGANA  1902   0.0   0.0   0.2  10.7   7.3   52.4  146.3  142.8
# 2     TELANGANA  1903  12.9   4.6   0.0   9.9  40.7   99.2  505.2  246.7
# 3     TELANGANA  1904   0.0   0.0  10.8   0.8  14.7  104.2  139.5   50.0
# 4     TELANGANA  1905   0.0   4.3  12.8  27.6  32.2  129.5   82.4  237.3
# ..          ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 110   TELANGANA  2011   0.0  11.9   2.6  25.6   9.3   83.9  268.2  225.9
# 111   TELANGANA  2012   6.7   0.0   0.2  14.0   8.4  124.4  300.3  229.9
# 112   TELANGANA  2013   2.4  29.0   0.2  24.4   8.5  213.4  453.8  230.6
# 113   TELANGANA  2014   0.2   2.9  58.3  10.3  73.3   62.3  146.0  205.2
# 114   TELANGANA  2015  17.5   0.0  43.0  65.7  23.3  266.9  104.4  160.5
#
#        SEP    OCT   NOV  DEC
# 0     77.7   75.5  12.2  0.0
# 1    190.5   41.7  31.2  7.3
# ...

# %%
plt.plot(TG['YEAR'],TG['JAN'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error
import seaborn as sns

# %% [markdown]
# ## JAN MODEL

# %%
plt.plot(TG['YEAR'],TG['JAN'])

# %%
x = TG.YEAR.values.reshape(-1, 1)
y = TG.JAN.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)

# %%
ModelJan = RandomForestRegressor()
ModelJan.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = ModelJan.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
rmse =  np.sqrt(mse)

# %%
rmse
# Out:
# 20.100990411277895

# %%
res = ModelJan.predict([[2010],[2025],[2030]])
res
# Out:
# array([ 6.804, 12.637, 12.637])

# %% [markdown]
# ## feb model

# %%
plt.plot(TG['YEAR'],TG['FEB'])

# %%
x = TG.YEAR.values.reshape(-1, 1)
y = TG.FEB.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
ModelFeb = RandomForestRegressor()
ModelFeb.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = ModelFeb.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
rmse =  np.sqrt(mse)
rmse
# Out:
# 13.46023911687061

# %%
res = ModelFeb.predict([[2010],[2025],[2030]])
res
# Out:
# array([5.129, 3.399, 3.399])

# %% [markdown]
# ## march model

# %%
plt.plot(TG['YEAR'],TG['MAR'])

# %%
x = TG.YEAR.values.reshape(-1, 1)
y = TG.MAR.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
ModelMar = RandomForestRegressor()
ModelMar.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = ModelMar.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
rmse =  np.sqrt(mse)
rmse
# Out:
# 17.28966828773762

# %%
res = ModelMar.predict([[2010],[2025],[2030]])
res
# Out:
# array([ 4.937, 40.123, 40.123])

# %% [markdown]
# ## april

# %%
plt.plot(TG['YEAR'],TG['APR'])

# %%
x = TG.YEAR.values.reshape(-1, 1)
y = TG.APR.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
ModelApr = RandomForestRegressor()
ModelApr.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = ModelApr.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
rmse =  np.sqrt(mse)
rmse
# Out:
# 30.268170718870117

# %%
res = ModelApr.predict([[2010],[2025],[2030]])
res
# Out:
# array([ 7.184, 43.675, 43.675])

# %% [markdown]
# ## may

# %%
plt.plot(TG['YEAR'],TG['MAY'])

# %%
x = TG.YEAR.values.reshape(-1, 1)
y = TG.MAY.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
ModelMay = RandomForestRegressor()
ModelMay.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = ModelMay.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
rmse =  np.sqrt(mse)
rmse
# Out:
# 25.8524253278746

# %%
res = ModelMay.predict([[2010],[2025],[2030]])
res
# Out:
# array([19.15, 29.88, 29.88])

# %% [markdown]
# ## June

# %%
plt.plot(TG['YEAR'],TG['JUN'])

# %%
x = TG.YEAR.values.reshape(-1, 1)
y = TG.JUN.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
ModelJun = RandomForestRegressor()
ModelJun.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = ModelJun.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
rmse =  np.sqrt(mse)
rmse
# Out:
# 65.17044767952724

# %%
res = ModelJun.predict([[2010],[2025],[2030]])
res
# Out:
# array([114.86, 198.25, 198.25])

# %% [markdown]
# ## july

# %%
plt.plot(TG['YEAR'],TG['JUL'])

# %%
x = TG.YEAR.values.reshape(-1, 1)
y = TG.JUL.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
ModelJul = RandomForestRegressor()
ModelJul.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = ModelJul.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
rmse =  np.sqrt(mse)
rmse
# Out:
# 92.7854497182433

# %%
res = ModelJun.predict([[2010],[2025],[2030]])
res
# Out:
# array([114.86, 198.25, 198.25])

# %% [markdown]
# ## Aug

# %%
plt.plot(TG['YEAR'],TG['AUG'])

# %%
x = TG.YEAR.values.reshape(-1, 1)
y = TG.AUG.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
ModelAug = RandomForestRegressor()
ModelAug.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = ModelAug.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
rmse =  np.sqrt(mse)
rmse
# Out:
# 108.20553456501204

# %%
res = ModelAug.predict([[2010],[2025],[2030]])
res
# Out:
# array([272.995, 184.651, 184.651])

# %% [markdown]
# ## Sep

# %%
plt.plot(TG['YEAR'],TG['SEP'])

# %%
x = TG.YEAR.values.reshape(-1, 1)
y = TG.SEP.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
ModelSep = RandomForestRegressor()
ModelSep.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = ModelSep.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
rmse =  np.sqrt(mse)
rmse
# Out:
# 60.548199588564806

# %%
res = ModelSep.predict([[2010],[2025],[2030]])
res
# Out:
# array([209.251, 156.605, 156.605])

# %% [markdown]
# ## oct

# %%
plt.plot(TG['YEAR'],TG['OCT'])

# %%
x = TG.YEAR.values.reshape(-1, 1)
y = TG.OCT.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
ModelOct = RandomForestRegressor()
ModelOct.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = ModelOct.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
rmse =  np.sqrt(mse)
rmse
# Out:
# 50.07095260228228

# %%
res = ModelOct.predict([[2010],[2025],[2030]])
res
# Out:
# array([78.742, 37.732, 37.732])

# %% [markdown]
# ## Nov

# %%
plt.plot(TG['YEAR'],TG['NOV'])

# %%
x = TG.YEAR.values.reshape(-1, 1)
y = TG.NOV.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
ModelNov = RandomForestRegressor()
ModelNov.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = ModelNov.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
rmse =  np.sqrt(mse)
rmse
# Out:
# 43.472486768453145

# %%
res = ModelNov.predict([[2010],[2025],[2030]])
res
# Out:
# array([33.443,  5.687,  5.687])

# %% [markdown]
# ## dec

# %%
plt.plot(TG['YEAR'],TG['DEC'])

# %%
x = TG.YEAR.values.reshape(-1, 1)
y = TG.DEC.values.reshape(-1, 1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
ModelDec = RandomForestRegressor()
ModelDec.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred = ModelDec.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
rmse =  np.sqrt(mse)
rmse
# Out:
# 11.962465116633224

# %%
res = ModelDec.predict([[2010],[2025],[2030]])
res
# Out:
# array([5.827, 1.505, 1.505])

# %%
dict = {
    'JAN' : ModelJan,
    'FEB' : ModelFeb,
    'MAR' : ModelMar,
    'APR' : ModelApr,
    'MAY' : ModelMay,
    'JUN' : ModelJun,
    'JUL' : ModelJul,
    'AUG' : ModelAug,
    'SEP' : ModelSep,
    'OCT' : ModelOct,
    'NOV' : ModelNov,
    'DEC' : ModelDec,
}

# %%
list = ['JUL','JUN','OCT']

# %%
def fun(year,month):
    return dict[month].predict([[year]])

# %%
res=fun(2026,'MAR')
res
# Out:
# array([40.123])

# %%
n=int(input())
for i in range (n):
    year=int(input("enter thE year"))
    month=input("enter the month")
    res=fun(year,month)
    if(res>110):
        print("YES,there is a possibility of flood")
    else:
        print("NO,there is no flood")
# Out:
#  1
# enter thE year 2020
# enter the month JAN
# NO,there is no flood

# %% [markdown]
# pickle

# %%
import pickle

# %%
pickle.dump(ModelJan,open('ModelJan.pkl','wb'))
pickle.dump(ModelFeb,open('ModelFeb.pkl','wb'))
pickle.dump(ModelMar,open('ModelMar.pkl','wb'))
pickle.dump(ModelApr,open('ModelApr.pkl','wb'))
pickle.dump(ModelMay,open('ModelMay.pkl','wb'))
pickle.dump(ModelJun,open('ModelJun.pkl','wb'))
pickle.dump(ModelJul,open('ModelJul.pkl','wb'))
pickle.dump(ModelAug,open('ModelAug.pkl','wb'))
pickle.dump(ModelSep,open('ModelSep.pkl','wb'))
pickle.dump(ModelOct,open('ModelOct.pkl','wb'))
pickle.dump(ModelNov,open('ModelNov.pkl','wb'))
pickle.dump(ModelDec,open('ModelDec.pkl','wb'))
